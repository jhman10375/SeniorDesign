# %%
# %pip install "fastapi[standard]"
# Out:
# ...
#    ---------------------------------------- 0.0/71.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/71.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/71.5 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/71.5 kB ? eta -:--:--
#    ----------------- ---------------------- 30.7/71.5 kB 445.2 kB/s eta 0:00:01
#    ---------------------------------- ----- 61.4/71.5 kB 550.5 kB/s eta 0:00:01
#    ---------------------------------------- 71.5/71.5 kB 561.6 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/63.7 kB ? eta -:--:--
#    -------------------------------------- - 61.4/63.7 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 63.7/63.7 kB 1.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/94.6 kB ? eta -:--:--
#    ---------------------------------------- 94.6/94.6 kB 2.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/307.7 kB ? eta -:--:--
# ...

# %%
# %fastapi dev main.py
# Out:
# INFO     Using path main.py
# INFO     Resolved absolute path C:\Users\juan_\anaconda3\jupyter\main.py
# INFO     Searching for package file structure from directories with __init__.py
#          files
# INFO     Importing from C:\Users\juan_\anaconda3\jupyter
#
#  +- Python module file -+
#  |                      |
#  |
# +--------------------- Traceback (most recent call last) ---------------------+
# | C:\Users\juan_\anaconda3\Lib\site-packages\fastapi_cli\cli.py:174 in dev    |
# |                                                                             |
# |   171                                                                       |
# |   172     Otherwise, it uses the first [bold]FastAPI[/bold] app found in th |
# |   173     """                                                               |
# | > 174     _run(                                                             |
# |   175         path=path,                                                    |
# ...
